# %%
import tensorflow as tf

import aux_code
import numpy as np

import os

import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# # Define folders

# %%
# Folder where the MLP weights are saved
model_folder           = os.path.join('.','model')
# Folder containing the dataset
dataset_folder = os.path.join('.','dataset')
# Folder where the quantized MLP weights will be saved
quantized_model_folder = os.path.join('.','quantized_model')
aux_code.create_folder(quantized_model_folder)
# Folder where the plots are saved
plots_folder = os.path.join('.','plots')
aux_code.create_folder(plots_folder)

# %% [markdown]
# # Quantized model weights

# %%
model = aux_code.define_mlp()
model.load_weights(os.path.join(model_folder, 'model_weights.h5'))
# Out:
# 2024-04-23 19:34:20.788434: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-23 19:34:20.788762: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
# Quantized weights
int_type = np.int32
SCALE    = 11

weightsI1 = model.trainable_variables[0].numpy()
bias1     = model.trainable_variables[1].numpy()
weights12 = model.trainable_variables[2].numpy()
bias2     = model.trainable_variables[3].numpy()
weights23 = model.trainable_variables[4].numpy()
bias3     = model.trainable_variables[5].numpy()
weights3O = model.trainable_variables[6].numpy()
biasO     = model.trainable_variables[7].numpy()


# Scale the weights by 2^SCALE
weightsI1 = (weightsI1 * (2 ** SCALE)).astype(int_type)
bias1 = (bias1 * (2 ** SCALE)).astype(int_type)
weights12 = (weights12 * (2 ** SCALE)).astype(int_type)
bias2 = (bias2 * (2 ** SCALE)).astype(int_type)
weights23 = (weights23 * (2 ** SCALE)).astype(int_type)
bias3 = (bias3 * (2 ** SCALE)).astype(int_type)
weights3O = (weights3O * (2 ** SCALE)).astype(int_type)
biasO = (biasO * (2 ** SCALE)).astype(int_type)

# %%
# Save quantized weights weights
np.save(os.path.join(quantized_model_folder, 'weightsI1'), weightsI1)
np.save(os.path.join(quantized_model_folder, 'bias1'), bias1)
np.save(os.path.join(quantized_model_folder, 'weights12'), weights12)
np.save(os.path.join(quantized_model_folder, 'bias2'), bias2)
np.save(os.path.join(quantized_model_folder, 'weights23'), weights23)
np.save(os.path.join(quantized_model_folder, 'bias3'), bias3)
np.save(os.path.join(quantized_model_folder, 'weights3O'), weights3O)
np.save(os.path.join(quantized_model_folder, 'biasO'), biasO)

# %% [markdown]
# # Load and normalize test set

# %%
test_set = np.load(os.path.join(dataset_folder, 'test_set.npz'))
x_test = aux_code.normalize_quantized_dataset(test_set['nn_data_test'].astype(int_type), SCALE=SCALE)
y_test = test_set['stx_flare_loc_test']
cfl_loc_test = test_set['cfl_loc_test']

# %%
y_pred_q = np.zeros((len(x_test),2), dtype=np.int16)
y_nn_norm_factor=4000

for i in range(len(x_test)):
    
    this_out = aux_code.nn_model(x_test[i,:], weightsI1, bias1, weights12, bias2, weights23, bias3, 
                                 weights3O, biasO, SCALE = SCALE)
    y_pred_q[i,:] = (this_out * y_nn_norm_factor + 2**(SCALE-1)) >> SCALE

# %%
# Plot results
x_fully_ill = 0.633*3600
y_fully_ill = 0.518*3600
xy_min_max = 4000

plt.rcParams["figure.figsize"] = [10, 10]
fig, axs = plt.subplots(2, 2)

axs[0,0].scatter(y_test[:,0],y_pred_q[:,0], alpha=0.3, label='NN prediction')
axs[0,0].plot([-x_fully_ill,-x_fully_ill],[-xy_min_max,xy_min_max], 'k--', label='Full-sensitivity FOV')
axs[0,0].plot([x_fully_ill,x_fully_ill],[-xy_min_max,xy_min_max], 'k--')
axs[0,0].set_xlim(-xy_min_max, xy_min_max)
axs[0,0].set_ylim(-xy_min_max, xy_min_max)
axs[0,0].plot([-xy_min_max,xy_min_max],[-xy_min_max,xy_min_max], color='r')

axs[0,0].set(title='X coordinate')
axs[0,0].title.set_size(15)
axs[0,0].xaxis.label.set_size(12)
axs[0,0].yaxis.label.set_size(12)
axs[0,0].tick_params(axis="x", labelsize=10)
axs[0,0].tick_params(axis="y", labelsize=10)
axs[0,0].set(xlabel='From imaging [arcsec]')
axs[0,0].set(ylabel='NN prediction [arcsec]')

axs[0,0].legend(loc="upper left", fontsize=10)

axs[0,1].scatter(y_test[:,1],y_pred_q[:,1], alpha=0.3, label='NN prediction')
axs[0,1].plot([-x_fully_ill,-x_fully_ill],[-xy_min_max,xy_min_max], 'k--', label='Full-sensitivity FOV')
axs[0,1].plot([x_fully_ill,x_fully_ill],[-xy_min_max,xy_min_max], 'k--')
axs[0,1].set_xlim(-xy_min_max, xy_min_max)
axs[0,1].set_ylim(-xy_min_max, xy_min_max)
axs[0,1].plot([-xy_min_max,xy_min_max],[-xy_min_max,xy_min_max], color='r')

axs[0,1].set(title='Y coordinate')
axs[0,1].title.set_size(15)
axs[0,1].xaxis.label.set_size(12)
axs[0,1].yaxis.label.set_size(12)
axs[0,1].tick_params(axis="x", labelsize=10)
axs[0,1].tick_params(axis="y", labelsize=10)
axs[0,1].set(xlabel='From imaging [arcsec]')

axs[0,1].legend(loc="upper left", fontsize=10)

axs[1,0].scatter(y_test[:,0],cfl_loc_test[:,0], alpha=0.3, label='CFL solution')
axs[1,0].plot([-x_fully_ill,-x_fully_ill],[-xy_min_max,xy_min_max], 'k--', label='Full-sensitivity FOV')
axs[1,0].plot([x_fully_ill,x_fully_ill],[-xy_min_max,xy_min_max], 'k--')
axs[1,0].set_xlim(-xy_min_max, xy_min_max)
axs[1,0].set_ylim(-xy_min_max, xy_min_max)
axs[1,0].plot([-xy_min_max,xy_min_max],[-xy_min_max,xy_min_max], color='r')

axs[1,0].title.set_size(15)
axs[1,0].xaxis.label.set_size(12)
axs[1,0].yaxis.label.set_size(12)
axs[1,0].tick_params(axis="x", labelsize=10)
axs[1,0].tick_params(axis="y", labelsize=10)
axs[1,0].set(xlabel='From imaging [arcsec]')
axs[1,0].set(ylabel='CFL solution [arcsec]')

axs[1,0].legend(loc="upper left", fontsize=10)

axs[1,1].scatter(y_test[:,1],cfl_loc_test[:,1], alpha=0.3, label='CFL solution')
axs[1,1].plot([-x_fully_ill,-x_fully_ill],[-xy_min_max,xy_min_max], 'k--', label='Full-sensitivity FOV')
axs[1,1].plot([x_fully_ill,x_fully_ill],[-xy_min_max,xy_min_max], 'k--')
axs[1,1].set_xlim(-xy_min_max, xy_min_max)
axs[1,1].set_ylim(-xy_min_max, xy_min_max)
axs[1,1].plot([-xy_min_max,xy_min_max],[-xy_min_max,xy_min_max], color='r')


axs[1,1].title.set_size(15)
axs[1,1].xaxis.label.set_size(12)
axs[1,1].yaxis.label.set_size(12)
axs[1,1].tick_params(axis="x", labelsize=10)
axs[1,1].tick_params(axis="y", labelsize=10)
axs[1,1].set(xlabel='From imaging [arcsec]')
axs[1,1].legend(loc="upper left", fontsize=10)

plt.savefig(os.path.join(plots_folder, 'predictions_quantized_weights.png'), bbox_inches='tight')
plt.show()

# %%
dist_nn_q  = np.sqrt( (y_test[:,0]-y_pred_q[:,0])**2 + (y_test[:,1]-y_pred_q[:,1])**2 )
dist_cfl = np.sqrt( (y_test[:,0]-cfl_loc_test[:,0])**2 + (y_test[:,1]-cfl_loc_test[:,1])**2 )

bins = np.linspace(0, 1000, num=101)

plt.figure(figsize=(7, 4))
SMALL_SIZE = 12
MEDIUM_SIZE = 15
BIGGER_SIZE = 18

plt.hist(dist_cfl,bins=bins, alpha=0.5,label='CFL solution')
plt.hist(dist_nn_q,bins=bins,alpha=0.5,label='MLP prediction')

plt.xlim(0,600)
plt.legend(loc="upper right")
plt.rc('font', size=SMALL_SIZE)        # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)   # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)  # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)  # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)  # legend fontsize

plt.xlabel("Distance [arcsec]")
plt.ylabel("Number of examples")

plt.savefig(os.path.join(plots_folder, 'hist_dist_nn_q.png'), bbox_inches='tight')

plt.show()
